# %%
import torch
import torch.nn as nn

# %%
x = torch.randn(2,3,32,32)


model = nn.Conv2d(3,5, kernel_size = 3)

# %%
for n, p in model.named_parameters():
  print(n, p.shape)
# Out:
# weight torch.Size([5, 3, 3, 3])
# bias torch.Size([5])
