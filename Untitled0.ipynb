# %%
import numpy as np

# %%
mat_a = np.array([[-1,6],[0,5],[3,4]])
mat_b = np.array([[-2,2],[0,1],[-1,0]])
def fisher_criterion(v1, v2):
    return np.square(abs(np.mean(v1) - np.mean(v2))) / (np.square(np.var(v1)) + np.square(np.var(v2)))
print(fisher_criterion(mat_a,mat_b))
# Out:
# 0.1797232634870183
